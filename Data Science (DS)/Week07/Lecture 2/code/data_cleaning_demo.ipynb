# %%
import pandas as pd

# %%
data = pd.read_csv("customer_shopping_preferences.csv")

# %%
data.head()
# Out:
#   Customer ID    Age  Gender Item Purchased     Category  \
# 0    CUST1000  51.25  Female            Bag      Apparel
# 1    CUST1001  19.30  Female          Shoes      Apparel
# 2    CUST1002  32.30    Male          Shoes      Apparel
# 3    CUST1003  29.61    Male     Headphones        Books
# 4    CUST1004  56.30  Female     Smartphone  Accessories
#
#    Purchase Amount (USD)     Location Size  Color  Season  Review Rating  \
# 0                 600.06      Phoenix   XL  White  Spring            3.0
# 1                 458.98  Los Angeles    L   Blue  Winter            1.2
# 2                 475.11      Phoenix    S  Green  Winter            4.6
# 3                 168.08      Chicago   XL  Black  Spring            3.7
# 4                 660.31      Chicago   XL  Black  Winter            4.6
#
#   Subscription Status Shipping Type Discount Applied Promo Code Used  \
# 0                  No      Standard              Yes              No
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   object
#  1   Age                     3900 non-null   float64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   float64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
data.describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  3900.000000            3900.000000    3900.000000         3900.000000
# mean     44.246256             502.545864       3.006077           25.109744
# std      14.933878             289.545735       1.154201           14.664488
# min      18.010000               5.060000       1.000000            0.000000
# 25%      31.450000             247.020000       2.000000           12.000000
# 50%      44.465000             508.290000       3.000000           25.000000
# 75%      57.100000             753.910000       4.000000           38.000000
# max      70.000000             999.760000       5.000000           50.000000

# %%
data.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
print(data.dtypes)
# Out:
# Customer ID                object
# Age                       float64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)     float64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases        float64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %%
# checking for duplicates
print(data.duplicated().sum())
# Out:
# 0

# %%
data["Age"] = data['Age'].fillna(data['Age'].median()) # imputing
data_cleaned = data.dropna() # drops any rows that have missing values
data.info()b
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   object
#  1   Age                     3900 non-null   float64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   float64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
data_cleaned = data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   object
#  1   Age                     3900 non-null   float64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   float64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
data['Gender'] = data['Gender'].str.upper()
data.head()
# Out:
#   Customer ID    Age  Gender Item Purchased     Category  \
# 0    CUST1000  51.25  FEMALE            Bag      Apparel
# 1    CUST1001  19.30  FEMALE          Shoes      Apparel
# 2    CUST1002  32.30    MALE          Shoes      Apparel
# 3    CUST1003  29.61    MALE     Headphones        Books
# 4    CUST1004  56.30  FEMALE     Smartphone  Accessories
#
#    Purchase Amount (USD)     Location Size  Color  Season  Review Rating  \
# 0                 600.06      Phoenix   XL  White  Spring            3.0
# 1                 458.98  Los Angeles    L   Blue  Winter            1.2
# 2                 475.11      Phoenix    S  Green  Winter            4.6
# 3                 168.08      Chicago   XL  Black  Spring            3.7
# 4                 660.31      Chicago   XL  Black  Winter            4.6
#
#   Subscription Status Shipping Type Discount Applied Promo Code Used  \
# 0                  No      Standard              Yes              No
# ...

# %%
data['Age'] = pd.to_numeric(data['Age'], errors='coerce')

# %%
from sklearn.preprocessing import MinMaxScaler
data['Scaled Amount'] = MinMaxScaler().fit_transform(data[['Purchase Amount (USD)']])
data['PaymentMethodScaled'] = data['Payment Method'].astype('category').cat.codes

data.head()
# Out:
#   Customer ID    Age  Gender Item Purchased     Category  \
# 0    CUST1000  51.25  FEMALE            Bag      Apparel
# 1    CUST1001  19.30  FEMALE          Shoes      Apparel
# 2    CUST1002  32.30    MALE          Shoes      Apparel
# 3    CUST1003  29.61    MALE     Headphones        Books
# 4    CUST1004  56.30  FEMALE     Smartphone  Accessories
#
#    Purchase Amount (USD)     Location Size  Color  Season  Review Rating  \
# 0                 600.06      Phoenix   XL  White  Spring            3.0
# 1                 458.98  Los Angeles    L   Blue  Winter            1.2
# 2                 475.11      Phoenix    S  Green  Winter            4.6
# 3                 168.08      Chicago   XL  Black  Spring            3.7
# 4                 660.31      Chicago   XL  Black  Winter            4.6
#
#   Subscription Status Shipping Type Discount Applied Promo Code Used  \
# 0                  No      Standard              Yes              No
# ...

# %%
aggregated_values = data.groupby('Subscription Status')['Age'].mean()
print(aggregated_values)
# Out:
# Subscription Status
# No     43.975291
# Yes    44.535315
# Name: Age, dtype: float64

# %%
data2 = pd.read_csv('customer_demographics.csv')
combined = pd.merge(data, data2, on='Customer ID', how='inner')

combined.head()
# Out:
#   Customer ID  Age_x Gender_x Item Purchased Category  Purchase Amount (USD)  \
# 0    CUST1000  51.25   FEMALE            Bag  Apparel                 600.06
#
#   Location_x Size  Color  Season  ...  Frequency of Purchases Scaled Amount  \
# 0    Phoenix   XL  White  Spring  ...               Quarterly       0.59817
#
#   PaymentMethodScaled Age_y Gender_y  Location_y  Income SubscriptionStatus  \
# 0                   1    32   Female     Chicago  119764                 No
#
#    PreferredPaymentMethod  ShoppingFrequency
# 0                    Cash             Weekly
#
# [1 rows x 27 columns]

# %%
data.describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases  \
# count  3900.000000            3900.000000    3900.000000         3900.000000
# mean     44.246256             502.545864       3.006077           25.109744
# std      14.933878             289.545735       1.154201           14.664488
# min      18.010000               5.060000       1.000000            0.000000
# 25%      31.450000             247.020000       2.000000           12.000000
# 50%      44.465000             508.290000       3.000000           25.000000
# 75%      57.100000             753.910000       4.000000           38.000000
# max      70.000000             999.760000       5.000000           50.000000
#
#        Scaled Amount  PaymentMethodScaled
# count    3900.000000          3900.000000
# mean        0.500137             1.498205
# std         0.291089             1.116569
# min         0.000000             0.000000
# 25%         0.243249             0.000000
# ...
